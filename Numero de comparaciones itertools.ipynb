# %% [markdown]
# ## Numero de comparaciones itertools

# %%
import itertools

# %%
def allpermutations(n):
    v=[]
    #Construir un arrelo de 1 hasta n
    for i in range(n):
        v.append(i+1)
    
    p = list(itertools.permutations(v)) # lista con todas las permutaciones de 
    
    return p

# %%
def isortCompare(a):
    #a es el arreglo con la permutacion aleatoria generada
    v = []
    
    #Construir un arreglo y le pasar toda la indormacion del arreglo "a" 
    for i in range(len(a)):
        v.append(a[i])
    
    #inicilizar contador de numero de comparaciones    
    nCompare = 0   
    for i in range(1,len(v)): 
        key = v[i] 
        j = i-1
        while (j > -1) and (v[j] > key): 
            v[j+1] = v[j] 
            j = j -1 
            nCompare = nCompare + 1
        nCompare = nCompare + 1
        v[j+1] = key 
        
    return nCompare

# %%
n = 5  #tamaño del arreglo que contendra la permutacion aleatoria.

sum = 0
min = n**3
max = 0

p = allpermutations(n) # Generar todas las permutaciones de n numeros

for i in range(len(p)):
    t = isortCompare(p[i]) 
    print "Numero comparaciones permutacion",i+1,":", t
# Out:
# Numero comparaciones permutacion 1 : 4
# Numero comparaciones permutacion 2 : 5
# Numero comparaciones permutacion 3 : 5
# Numero comparaciones permutacion 4 : 6
# Numero comparaciones permutacion 5 : 6
# Numero comparaciones permutacion 6 : 7
# Numero comparaciones permutacion 7 : 5
# Numero comparaciones permutacion 8 : 6
# Numero comparaciones permutacion 9 : 6
# Numero comparaciones permutacion 10 : 7
# Numero comparaciones permutacion 11 : 7
# Numero comparaciones permutacion 12 : 8
# Numero comparaciones permutacion 13 : 6
# Numero comparaciones permutacion 14 : 7
# Numero comparaciones permutacion 15 : 7
# Numero comparaciones permutacion 16 : 8
# Numero comparaciones permutacion 17 : 8
# Numero comparaciones permutacion 18 : 9
# Numero comparaciones permutacion 19 : 7
# Numero comparaciones permutacion 20 : 8
# Numero comparaciones permutacion 21 : 8
# Numero comparaciones permutacion 22 : 9
# Numero comparaciones permutacion 23 : 9
# Numero comparaciones permutacion 24 : 10
# Numero comparaciones permutacion 25 : 5
# Numero comparaciones permutacion 26 : 6
# Numero comparaciones permutacion 27 : 6
# Numero comparaciones permutacion 28 : 7
# Numero comparaciones permutacion 29 : 7
# Numero comparaciones permutacion 30 : 8
# Numero comparaciones permutacion 31 : 6
# Numero comparaciones permutacion 32 : 7
# Numero comparaciones permutacion 33 : 7
# Numero comparaciones permutacion 34 : 8
# Numero comparaciones permutacion 35 : 8
# Numero comparaciones permutacion 36 : 9
# Numero comparaciones permutacion 37 : 7
# Numero comparaciones permutacion 38 : 8
# Numero comparaciones permutacion 39 : 8
# Numero comparaciones permutacion 40 : 9
# Numero comparaciones permutacion 41 : 9
# Numero comparaciones permutacion 42 : 10
# Numero comparaciones permutacion 43 : 8
# Numero comparaciones permutacion 44 : 9
# Numero comparaciones permutacion 45 : 9
# Numero comparaciones permutacion 46 : 10
# Numero comparaciones permutacion 47 : 10
# Numero comparaciones permutacion 48 : 11
# Numero comparaciones permutacion 49 : 6
# Numero comparaciones permutacion 50 : 7
# Numero comparaciones permutacion 51 : 7
# Numero comparaciones permutacion 52 : 8
# Numero comparaciones permutacion 53 : 8
# Numero comparaciones permutacion 54 : 9
# Numero comparaciones permutacion 55 : 7
# Numero comparaciones permutacion 56 : 8
# Numero comparaciones permutacion 57 : 8
# Numero comparaciones permutacion 58 : 9
# Numero comparaciones permutacion 59 : 9
# Numero comparaciones permutacion 60 : 10
# Numero comparaciones permutacion 61 : 8
# Numero comparaciones permutacion 62 : 9
# Numero comparaciones permutacion 63 : 9
# Numero comparaciones permutacion 64 : 10
# Numero comparaciones permutacion 65 : 10
# Numero comparaciones permutacion 66 : 11
# Numero comparaciones permutacion 67 : 9
# Numero comparaciones permutacion 68 : 10
# Numero comparaciones permutacion 69 : 10
# Numero comparaciones permutacion 70 : 11
# Numero comparaciones permutacion 71 : 11
# Numero comparaciones permutacion 72 : 12
# Numero comparaciones permutacion 73 : 7
# Numero comparaciones permutacion 74 : 8
# Numero comparaciones permutacion 75 : 8
# Numero comparaciones permutacion 76 : 9
# Numero comparaciones permutacion 77 : 9
# Numero comparaciones permutacion 78 : 10
# Numero comparaciones permutacion 79 : 8
# Numero comparaciones permutacion 80 : 9
# Numero comparaciones permutacion 81 : 9
# Numero comparaciones permutacion 82 : 10
# Numero comparaciones permutacion 83 : 10
# Numero comparaciones permutacion 84 : 11
# Numero comparaciones permutacion 85 : 9
# Numero comparaciones permutacion 86 : 10
# Numero comparaciones permutacion 87 : 10
# Numero comparaciones permutacion 88 : 11
# Numero comparaciones permutacion 89 : 11
# Numero comparaciones permutacion 90 : 12
# Numero comparaciones permutacion 91 : 10
# Numero comparaciones permutacion 92 : 11
# Numero comparaciones permutacion 93 : 11
# Numero comparaciones permutacion 94 : 12
# Numero comparaciones permutacion 95 : 12
# Numero comparaciones permutacion 96 : 13
# Numero comparaciones permutacion 97 : 8
# Numero comparaciones permutacion 98 : 9
# Numero comparaciones permutacion 99 : 9
# Numero comparaciones permutacion 100 : 10
# Numero comparaciones permutacion 101 : 10
# Numero comparaciones permutacion 102 : 11
# Numero comparaciones permutacion 103 : 9
# Numero comparaciones permutacion 104 : 10
# Numero comparaciones permutacion 105 : 10
# Numero comparaciones permutacion 106 : 11
# Numero comparaciones permutacion 107 : 11
# Numero comparaciones permutacion 108 : 12
# Numero comparaciones permutacion 109 : 10
# Numero comparaciones permutacion 110 : 11
# Numero comparaciones permutacion 111 : 11
# Numero comparaciones permutacion 112 : 12
# Numero comparaciones permutacion 113 : 12
# Numero comparaciones permutacion 114 : 13
# Numero comparaciones permutacion 115 : 11
# Numero comparaciones permutacion 116 : 12
# Numero comparaciones permutacion 117 : 12
# Numero comparaciones permutacion 118 : 13
# Numero comparaciones permutacion 119 : 13
# Numero comparaciones permutacion 120 : 14
