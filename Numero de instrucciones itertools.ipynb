# %% [markdown]
# ## Numero de instrucciones itertools

# %%
import random
import itertools

# %%
def allpermutations(n):
    v=[]
    #Construir un arrelo de 1 hasta n
    for i in range(n):
        v.append(i+1)
    
    p = list(itertools.permutations(v)) # lista con todas las permutaciones de 
    
    return p

# %%
def isortCompare(a):
    #a es el arreglo con la permutacion aleatoria generada
    v = []
    
    #Construir un arreglo y le pasar toda la indormacion del arreglo "a" 
    for i in range(len(a)):
        v.append(a[i])
    
    #inicilizar contador de numero de comparaciones    
    nCompare = 0   
    for i in range(1,len(v)): 
        key = v[i] 
        j = i-1
        while (j > -1) and (v[j] > key): 
            v[j+1] = v[j] 
            j = j -1 
            nCompare = nCompare + 1
        nCompare = nCompare + 1
        v[j+1] = key 
        
    return nCompare

# %%
n = 5  #tamaño del arreglo que contendra la permutacion aleatoria.

sum = 0
min = n**3
max = 0

p = allpermutations(n) # Generar todas las permutaciones de n numeros

for i in range(len(p)):
    t = isortCompare(p[i]) 
    print "Numero instrucciones permutacion",i+1,":", t
    if t < min :
       min = t
    if t > max :
       max = t
    sum = sum + t
    
print 'Theoretical best time, ' + str(5*n - 4) 
print 'Theoretical worst time,' + str((3.0/2.0)*n**2 + (7.0/2.0)*n - 4)
print 'Theoretical average time,' + str((3.0/4.0)*n**2 + (17.0/4.0)*n - 4)
print 'Experimenal best time, ' + str(min)
print 'Experimenal worst time,' + str(max)
print 'Experimenal average time,' + str(sum/len(p))
# Out:
# Numero instrucciones permutacion 1 : 4
# Numero instrucciones permutacion 2 : 5
# Numero instrucciones permutacion 3 : 5
# Numero instrucciones permutacion 4 : 6
# Numero instrucciones permutacion 5 : 6
# Numero instrucciones permutacion 6 : 7
# Numero instrucciones permutacion 7 : 5
# Numero instrucciones permutacion 8 : 6
# Numero instrucciones permutacion 9 : 6
# Numero instrucciones permutacion 10 : 7
# Numero instrucciones permutacion 11 : 7
# Numero instrucciones permutacion 12 : 8
# Numero instrucciones permutacion 13 : 6
# Numero instrucciones permutacion 14 : 7
# Numero instrucciones permutacion 15 : 7
# Numero instrucciones permutacion 16 : 8
# Numero instrucciones permutacion 17 : 8
# Numero instrucciones permutacion 18 : 9
# Numero instrucciones permutacion 19 : 7
# Numero instrucciones permutacion 20 : 8
# Numero instrucciones permutacion 21 : 8
# Numero instrucciones permutacion 22 : 9
# Numero instrucciones permutacion 23 : 9
# Numero instrucciones permutacion 24 : 10
# Numero instrucciones permutacion 25 : 5
# Numero instrucciones permutacion 26 : 6
# Numero instrucciones permutacion 27 : 6
# Numero instrucciones permutacion 28 : 7
# Numero instrucciones permutacion 29 : 7
# Numero instrucciones permutacion 30 : 8
# Numero instrucciones permutacion 31 : 6
# Numero instrucciones permutacion 32 : 7
# Numero instrucciones permutacion 33 : 7
# Numero instrucciones permutacion 34 : 8
# Numero instrucciones permutacion 35 : 8
# Numero instrucciones permutacion 36 : 9
# Numero instrucciones permutacion 37 : 7
# Numero instrucciones permutacion 38 : 8
# Numero instrucciones permutacion 39 : 8
# Numero instrucciones permutacion 40 : 9
# Numero instrucciones permutacion 41 : 9
# Numero instrucciones permutacion 42 : 10
# Numero instrucciones permutacion 43 : 8
# Numero instrucciones permutacion 44 : 9
# Numero instrucciones permutacion 45 : 9
# Numero instrucciones permutacion 46 : 10
# Numero instrucciones permutacion 47 : 10
# Numero instrucciones permutacion 48 : 11
# Numero instrucciones permutacion 49 : 6
# Numero instrucciones permutacion 50 : 7
# Numero instrucciones permutacion 51 : 7
# Numero instrucciones permutacion 52 : 8
# Numero instrucciones permutacion 53 : 8
# Numero instrucciones permutacion 54 : 9
# Numero instrucciones permutacion 55 : 7
# Numero instrucciones permutacion 56 : 8
# Numero instrucciones permutacion 57 : 8
# Numero instrucciones permutacion 58 : 9
# Numero instrucciones permutacion 59 : 9
# Numero instrucciones permutacion 60 : 10
# Numero instrucciones permutacion 61 : 8
# Numero instrucciones permutacion 62 : 9
# Numero instrucciones permutacion 63 : 9
# Numero instrucciones permutacion 64 : 10
# Numero instrucciones permutacion 65 : 10
# Numero instrucciones permutacion 66 : 11
# Numero instrucciones permutacion 67 : 9
# Numero instrucciones permutacion 68 : 10
# Numero instrucciones permutacion 69 : 10
# Numero instrucciones permutacion 70 : 11
# Numero instrucciones permutacion 71 : 11
# Numero instrucciones permutacion 72 : 12
# Numero instrucciones permutacion 73 : 7
# Numero instrucciones permutacion 74 : 8
# Numero instrucciones permutacion 75 : 8
# Numero instrucciones permutacion 76 : 9
# Numero instrucciones permutacion 77 : 9
# Numero instrucciones permutacion 78 : 10
# Numero instrucciones permutacion 79 : 8
# Numero instrucciones permutacion 80 : 9
# Numero instrucciones permutacion 81 : 9
# Numero instrucciones permutacion 82 : 10
# Numero instrucciones permutacion 83 : 10
# Numero instrucciones permutacion 84 : 11
# Numero instrucciones permutacion 85 : 9
# Numero instrucciones permutacion 86 : 10
# Numero instrucciones permutacion 87 : 10
# Numero instrucciones permutacion 88 : 11
# Numero instrucciones permutacion 89 : 11
# Numero instrucciones permutacion 90 : 12
# Numero instrucciones permutacion 91 : 10
# Numero instrucciones permutacion 92 : 11
# Numero instrucciones permutacion 93 : 11
# Numero instrucciones permutacion 94 : 12
# Numero instrucciones permutacion 95 : 12
# Numero instrucciones permutacion 96 : 13
# Numero instrucciones permutacion 97 : 8
# Numero instrucciones permutacion 98 : 9
# Numero instrucciones permutacion 99 : 9
# Numero instrucciones permutacion 100 : 10
# Numero instrucciones permutacion 101 : 10
# Numero instrucciones permutacion 102 : 11
# Numero instrucciones permutacion 103 : 9
# Numero instrucciones permutacion 104 : 10
# Numero instrucciones permutacion 105 : 10
# Numero instrucciones permutacion 106 : 11
# Numero instrucciones permutacion 107 : 11
# Numero instrucciones permutacion 108 : 12
# Numero instrucciones permutacion 109 : 10
# Numero instrucciones permutacion 110 : 11
# Numero instrucciones permutacion 111 : 11
# Numero instrucciones permutacion 112 : 12
# Numero instrucciones permutacion 113 : 12
# Numero instrucciones permutacion 114 : 13
# Numero instrucciones permutacion 115 : 11
# Numero instrucciones permutacion 116 : 12
# Numero instrucciones permutacion 117 : 12
# Numero instrucciones permutacion 118 : 13
# Numero instrucciones permutacion 119 : 13
# Numero instrucciones permutacion 120 : 14
# Theoretical best time, 21
# Theoretical worst time,51.0
# Theoretical average time,36.0
# Experimenal best time, 4
# Experimenal worst time,14
# Experimenal average time,9
