# %% [markdown]
# ## Numero de instrucciones itertools

# %%
import itertools

# %%
def allpermutations(n):
    v=[]
    #Construir un arrelo de 1 hasta n
    for i in range(n):
        v.append(i+1)
    
    p = list(itertools.permutations(v)) # lista con todas las permutaciones de 
    
    return p

# %%
def isortSteps(a):
    #a es el arreglo con la permutacion aleatoria generada
    v = []
    #Construir un arreglo y le pasar toda la indormacion del arreglo "a" 
    for i in range(len(a)):
        v.append(a[i])
        
    steps = 0 #inicilizo contador de numero de pasos
    
    for i in range(1,len(v)): #paso 1 -for
        key = v[i] #paso 2 -for
        j = i-1 #paso3 -for
        while (j > -1) and (v[j] > key): #paso1 -while
            v[j+1] = v[j] #paso2 -while
            j = j -1 #paso3 -while
            steps = steps + 3
        steps = steps + 1   #== 1 paso cuando pregunta y no se cumple el while ==
        v[j+1] = key #paso 4 -for
        steps = steps + 4  # == 4 pasos del for ==
    steps = steps + 1  #== 1 paso cuando pregunta y no se cumple el for ==
    return steps

# %%
n = 5  #tamaño del arreglo al que se le calcularan todas las permutaciones.

sum = 0
min = n**3
max = 0

p = allpermutations(n) # Generar todas las permutaciones de n numeros

for i in range(len(p)):
    t = isortSteps(p[i]) 
    print "Numero instrucciones permutacion",i+1,":", t
    if t < min :
       min = t
    if t > max :
       max = t
    sum = sum + t
    
print 'Theoretical best time, ' + str(5*n - 4) 
print 'Theoretical worst time,' + str((3.0/2.0)*n**2 + (7.0/2.0)*n - 4)
print 'Theoretical average time,' + str((3.0/4.0)*n**2 + (17.0/4.0)*n - 4)
print 'Experimenal best time, ' + str(min)
print 'Experimenal worst time,' + str(max)
print 'Experimenal average time,' + str(sum/len(p))
# Out:
# Numero instrucciones permutacion 1 : 21
# Numero instrucciones permutacion 2 : 24
# Numero instrucciones permutacion 3 : 24
# Numero instrucciones permutacion 4 : 27
# Numero instrucciones permutacion 5 : 27
# Numero instrucciones permutacion 6 : 30
# Numero instrucciones permutacion 7 : 24
# Numero instrucciones permutacion 8 : 27
# Numero instrucciones permutacion 9 : 27
# Numero instrucciones permutacion 10 : 30
# Numero instrucciones permutacion 11 : 30
# Numero instrucciones permutacion 12 : 33
# Numero instrucciones permutacion 13 : 27
# Numero instrucciones permutacion 14 : 30
# Numero instrucciones permutacion 15 : 30
# Numero instrucciones permutacion 16 : 33
# Numero instrucciones permutacion 17 : 33
# Numero instrucciones permutacion 18 : 36
# Numero instrucciones permutacion 19 : 30
# Numero instrucciones permutacion 20 : 33
# Numero instrucciones permutacion 21 : 33
# Numero instrucciones permutacion 22 : 36
# Numero instrucciones permutacion 23 : 36
# Numero instrucciones permutacion 24 : 39
# Numero instrucciones permutacion 25 : 24
# Numero instrucciones permutacion 26 : 27
# Numero instrucciones permutacion 27 : 27
# Numero instrucciones permutacion 28 : 30
# Numero instrucciones permutacion 29 : 30
# Numero instrucciones permutacion 30 : 33
# Numero instrucciones permutacion 31 : 27
# Numero instrucciones permutacion 32 : 30
# Numero instrucciones permutacion 33 : 30
# Numero instrucciones permutacion 34 : 33
# Numero instrucciones permutacion 35 : 33
# Numero instrucciones permutacion 36 : 36
# Numero instrucciones permutacion 37 : 30
# Numero instrucciones permutacion 38 : 33
# Numero instrucciones permutacion 39 : 33
# Numero instrucciones permutacion 40 : 36
# Numero instrucciones permutacion 41 : 36
# Numero instrucciones permutacion 42 : 39
# Numero instrucciones permutacion 43 : 33
# Numero instrucciones permutacion 44 : 36
# Numero instrucciones permutacion 45 : 36
# Numero instrucciones permutacion 46 : 39
# Numero instrucciones permutacion 47 : 39
# Numero instrucciones permutacion 48 : 42
# Numero instrucciones permutacion 49 : 27
# Numero instrucciones permutacion 50 : 30
# Numero instrucciones permutacion 51 : 30
# Numero instrucciones permutacion 52 : 33
# Numero instrucciones permutacion 53 : 33
# Numero instrucciones permutacion 54 : 36
# Numero instrucciones permutacion 55 : 30
# Numero instrucciones permutacion 56 : 33
# Numero instrucciones permutacion 57 : 33
# Numero instrucciones permutacion 58 : 36
# Numero instrucciones permutacion 59 : 36
# Numero instrucciones permutacion 60 : 39
# Numero instrucciones permutacion 61 : 33
# Numero instrucciones permutacion 62 : 36
# Numero instrucciones permutacion 63 : 36
# Numero instrucciones permutacion 64 : 39
# Numero instrucciones permutacion 65 : 39
# Numero instrucciones permutacion 66 : 42
# Numero instrucciones permutacion 67 : 36
# Numero instrucciones permutacion 68 : 39
# Numero instrucciones permutacion 69 : 39
# Numero instrucciones permutacion 70 : 42
# Numero instrucciones permutacion 71 : 42
# Numero instrucciones permutacion 72 : 45
# Numero instrucciones permutacion 73 : 30
# Numero instrucciones permutacion 74 : 33
# Numero instrucciones permutacion 75 : 33
# Numero instrucciones permutacion 76 : 36
# Numero instrucciones permutacion 77 : 36
# Numero instrucciones permutacion 78 : 39
# Numero instrucciones permutacion 79 : 33
# Numero instrucciones permutacion 80 : 36
# Numero instrucciones permutacion 81 : 36
# Numero instrucciones permutacion 82 : 39
# Numero instrucciones permutacion 83 : 39
# Numero instrucciones permutacion 84 : 42
# Numero instrucciones permutacion 85 : 36
# Numero instrucciones permutacion 86 : 39
# Numero instrucciones permutacion 87 : 39
# Numero instrucciones permutacion 88 : 42
# Numero instrucciones permutacion 89 : 42
# Numero instrucciones permutacion 90 : 45
# Numero instrucciones permutacion 91 : 39
# Numero instrucciones permutacion 92 : 42
# Numero instrucciones permutacion 93 : 42
# Numero instrucciones permutacion 94 : 45
# Numero instrucciones permutacion 95 : 45
# Numero instrucciones permutacion 96 : 48
# Numero instrucciones permutacion 97 : 33
# Numero instrucciones permutacion 98 : 36
# Numero instrucciones permutacion 99 : 36
# Numero instrucciones permutacion 100 : 39
# Numero instrucciones permutacion 101 : 39
# Numero instrucciones permutacion 102 : 42
# Numero instrucciones permutacion 103 : 36
# Numero instrucciones permutacion 104 : 39
# Numero instrucciones permutacion 105 : 39
# Numero instrucciones permutacion 106 : 42
# Numero instrucciones permutacion 107 : 42
# Numero instrucciones permutacion 108 : 45
# Numero instrucciones permutacion 109 : 39
# Numero instrucciones permutacion 110 : 42
# Numero instrucciones permutacion 111 : 42
# Numero instrucciones permutacion 112 : 45
# Numero instrucciones permutacion 113 : 45
# Numero instrucciones permutacion 114 : 48
# Numero instrucciones permutacion 115 : 42
# Numero instrucciones permutacion 116 : 45
# Numero instrucciones permutacion 117 : 45
# Numero instrucciones permutacion 118 : 48
# Numero instrucciones permutacion 119 : 48
# Numero instrucciones permutacion 120 : 51
# Theoretical best time, 21
# Theoretical worst time,51.0
# Theoretical average time,36.0
# Experimenal best time, 21
# Experimenal worst time,51
# Experimenal average time,36
