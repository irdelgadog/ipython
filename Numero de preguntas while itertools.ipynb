# %% [markdown]
# ## Numero de preguntas while itertools

# %%
import itertools

# %%
def allpermutations(n):
    v=[]
    #Construir un arrelo de 1 hasta n
    for i in range(n):
        v.append(i+1)
    
    p = list(itertools.permutations(v)) # lista con todas las permutaciones de 
    
    return p

# %%
def isortQwhile(a):
    #a es el arreglo con la permutacion aleatoria generada
    v = []
    
    #Construir un arreglo y le pasar toda la indormacion del arreglo "a" 
    for i in range(len(a)):
        v.append(a[i])
    
    #inicilizar contador de numero de comparaciones    
    nQwhile = 0   
    for i in range(1,len(v)): 
        key = v[i] 
        j = i-1
        while (j > -1) and (v[j] > key): 
            v[j+1] = v[j] 
            j = j -1 
            nQwhile = nQwhile + 2
        nQwhile = nQwhile + 2
        v[j+1] = key 
        
    return nQwhile

# %%
n = 5  #tamaño del arreglo al que se le calcularan todas las permutaciones.
sum = 0
min = n**3
max = 0

p = allpermutations(n) # Generar todas las permutaciones de n numeros

for i in range(len(p)):
    t = isortQwhile(p[i]) 
    print "Numero Numero preguntas en while - permutacion",i+1,":", t
# Out:
# Numero Numero preguntas en while - permutacion 1 : 8
# Numero Numero preguntas en while - permutacion 2 : 10
# Numero Numero preguntas en while - permutacion 3 : 10
# Numero Numero preguntas en while - permutacion 4 : 12
# Numero Numero preguntas en while - permutacion 5 : 12
# Numero Numero preguntas en while - permutacion 6 : 14
# Numero Numero preguntas en while - permutacion 7 : 10
# Numero Numero preguntas en while - permutacion 8 : 12
# Numero Numero preguntas en while - permutacion 9 : 12
# Numero Numero preguntas en while - permutacion 10 : 14
# Numero Numero preguntas en while - permutacion 11 : 14
# Numero Numero preguntas en while - permutacion 12 : 16
# Numero Numero preguntas en while - permutacion 13 : 12
# Numero Numero preguntas en while - permutacion 14 : 14
# Numero Numero preguntas en while - permutacion 15 : 14
# Numero Numero preguntas en while - permutacion 16 : 16
# Numero Numero preguntas en while - permutacion 17 : 16
# Numero Numero preguntas en while - permutacion 18 : 18
# Numero Numero preguntas en while - permutacion 19 : 14
# Numero Numero preguntas en while - permutacion 20 : 16
# Numero Numero preguntas en while - permutacion 21 : 16
# Numero Numero preguntas en while - permutacion 22 : 18
# Numero Numero preguntas en while - permutacion 23 : 18
# Numero Numero preguntas en while - permutacion 24 : 20
# Numero Numero preguntas en while - permutacion 25 : 10
# Numero Numero preguntas en while - permutacion 26 : 12
# Numero Numero preguntas en while - permutacion 27 : 12
# Numero Numero preguntas en while - permutacion 28 : 14
# Numero Numero preguntas en while - permutacion 29 : 14
# Numero Numero preguntas en while - permutacion 30 : 16
# Numero Numero preguntas en while - permutacion 31 : 12
# Numero Numero preguntas en while - permutacion 32 : 14
# Numero Numero preguntas en while - permutacion 33 : 14
# Numero Numero preguntas en while - permutacion 34 : 16
# Numero Numero preguntas en while - permutacion 35 : 16
# Numero Numero preguntas en while - permutacion 36 : 18
# Numero Numero preguntas en while - permutacion 37 : 14
# Numero Numero preguntas en while - permutacion 38 : 16
# Numero Numero preguntas en while - permutacion 39 : 16
# Numero Numero preguntas en while - permutacion 40 : 18
# Numero Numero preguntas en while - permutacion 41 : 18
# Numero Numero preguntas en while - permutacion 42 : 20
# Numero Numero preguntas en while - permutacion 43 : 16
# Numero Numero preguntas en while - permutacion 44 : 18
# Numero Numero preguntas en while - permutacion 45 : 18
# Numero Numero preguntas en while - permutacion 46 : 20
# Numero Numero preguntas en while - permutacion 47 : 20
# Numero Numero preguntas en while - permutacion 48 : 22
# Numero Numero preguntas en while - permutacion 49 : 12
# Numero Numero preguntas en while - permutacion 50 : 14
# Numero Numero preguntas en while - permutacion 51 : 14
# Numero Numero preguntas en while - permutacion 52 : 16
# Numero Numero preguntas en while - permutacion 53 : 16
# Numero Numero preguntas en while - permutacion 54 : 18
# Numero Numero preguntas en while - permutacion 55 : 14
# Numero Numero preguntas en while - permutacion 56 : 16
# Numero Numero preguntas en while - permutacion 57 : 16
# Numero Numero preguntas en while - permutacion 58 : 18
# Numero Numero preguntas en while - permutacion 59 : 18
# Numero Numero preguntas en while - permutacion 60 : 20
# Numero Numero preguntas en while - permutacion 61 : 16
# Numero Numero preguntas en while - permutacion 62 : 18
# Numero Numero preguntas en while - permutacion 63 : 18
# Numero Numero preguntas en while - permutacion 64 : 20
# Numero Numero preguntas en while - permutacion 65 : 20
# Numero Numero preguntas en while - permutacion 66 : 22
# Numero Numero preguntas en while - permutacion 67 : 18
# Numero Numero preguntas en while - permutacion 68 : 20
# Numero Numero preguntas en while - permutacion 69 : 20
# Numero Numero preguntas en while - permutacion 70 : 22
# Numero Numero preguntas en while - permutacion 71 : 22
# Numero Numero preguntas en while - permutacion 72 : 24
# Numero Numero preguntas en while - permutacion 73 : 14
# Numero Numero preguntas en while - permutacion 74 : 16
# Numero Numero preguntas en while - permutacion 75 : 16
# Numero Numero preguntas en while - permutacion 76 : 18
# Numero Numero preguntas en while - permutacion 77 : 18
# Numero Numero preguntas en while - permutacion 78 : 20
# Numero Numero preguntas en while - permutacion 79 : 16
# Numero Numero preguntas en while - permutacion 80 : 18
# Numero Numero preguntas en while - permutacion 81 : 18
# Numero Numero preguntas en while - permutacion 82 : 20
# Numero Numero preguntas en while - permutacion 83 : 20
# Numero Numero preguntas en while - permutacion 84 : 22
# Numero Numero preguntas en while - permutacion 85 : 18
# Numero Numero preguntas en while - permutacion 86 : 20
# Numero Numero preguntas en while - permutacion 87 : 20
# Numero Numero preguntas en while - permutacion 88 : 22
# Numero Numero preguntas en while - permutacion 89 : 22
# Numero Numero preguntas en while - permutacion 90 : 24
# Numero Numero preguntas en while - permutacion 91 : 20
# Numero Numero preguntas en while - permutacion 92 : 22
# Numero Numero preguntas en while - permutacion 93 : 22
# Numero Numero preguntas en while - permutacion 94 : 24
# Numero Numero preguntas en while - permutacion 95 : 24
# Numero Numero preguntas en while - permutacion 96 : 26
# Numero Numero preguntas en while - permutacion 97 : 16
# Numero Numero preguntas en while - permutacion 98 : 18
# Numero Numero preguntas en while - permutacion 99 : 18
# Numero Numero preguntas en while - permutacion 100 : 20
# Numero Numero preguntas en while - permutacion 101 : 20
# Numero Numero preguntas en while - permutacion 102 : 22
# Numero Numero preguntas en while - permutacion 103 : 18
# Numero Numero preguntas en while - permutacion 104 : 20
# Numero Numero preguntas en while - permutacion 105 : 20
# Numero Numero preguntas en while - permutacion 106 : 22
# Numero Numero preguntas en while - permutacion 107 : 22
# Numero Numero preguntas en while - permutacion 108 : 24
# Numero Numero preguntas en while - permutacion 109 : 20
# Numero Numero preguntas en while - permutacion 110 : 22
# Numero Numero preguntas en while - permutacion 111 : 22
# Numero Numero preguntas en while - permutacion 112 : 24
# Numero Numero preguntas en while - permutacion 113 : 24
# Numero Numero preguntas en while - permutacion 114 : 26
# Numero Numero preguntas en while - permutacion 115 : 22
# Numero Numero preguntas en while - permutacion 116 : 24
# Numero Numero preguntas en while - permutacion 117 : 24
# Numero Numero preguntas en while - permutacion 118 : 26
# Numero Numero preguntas en while - permutacion 119 : 26
# Numero Numero preguntas en while - permutacion 120 : 28
