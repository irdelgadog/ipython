# %% [markdown]
# ## Numero de swaps itertools

# %%
import itertools

# %%
def allpermutations(n):
    v=[]
    #Construir un arrelo de 1 hasta n
    for i in range(n):
        v.append(i+1)
    
    p = list(itertools.permutations(v)) # lista con todas las permutaciones de 
    
    return p

# %%
def isortSwap(a):
    #a es el arreglo con la permutacion aleatoria generada
    v = []
    
    #Construir un arreglo y le pasar toda la indormacion del arreglo "a" 
    for i in range(len(a)):
        v.append(a[i])
    
    #inicilizar contador de numero de comparaciones    
    nSwap = 0   
    for i in range(1,len(v)): 
        key = v[i] 
        j = i-1
        while (j > -1) and (v[j] > key): 
            v[j+1] = v[j] 
            j = j -1 
            nSwap = nSwap + 1

        v[j+1] = key 
        
    return nSwap

# %%
n = 5  #tamaño del arreglo al que se le calcularan todas las permutaciones.
sum = 0
min = n**3
max = 0

p = allpermutations(n) # Generar todas las permutaciones de n numeros

for i in range(len(p)):
    t = isortSwap(p[i]) 
    print "Numero Numero swaps - permutacion",i+1,":", t
# Out:
# Numero Numero swaps - permutacion 1 : 0
# Numero Numero swaps - permutacion 2 : 1
# Numero Numero swaps - permutacion 3 : 1
# Numero Numero swaps - permutacion 4 : 2
# Numero Numero swaps - permutacion 5 : 2
# Numero Numero swaps - permutacion 6 : 3
# Numero Numero swaps - permutacion 7 : 1
# Numero Numero swaps - permutacion 8 : 2
# Numero Numero swaps - permutacion 9 : 2
# Numero Numero swaps - permutacion 10 : 3
# Numero Numero swaps - permutacion 11 : 3
# Numero Numero swaps - permutacion 12 : 4
# Numero Numero swaps - permutacion 13 : 2
# Numero Numero swaps - permutacion 14 : 3
# Numero Numero swaps - permutacion 15 : 3
# Numero Numero swaps - permutacion 16 : 4
# Numero Numero swaps - permutacion 17 : 4
# Numero Numero swaps - permutacion 18 : 5
# Numero Numero swaps - permutacion 19 : 3
# Numero Numero swaps - permutacion 20 : 4
# Numero Numero swaps - permutacion 21 : 4
# Numero Numero swaps - permutacion 22 : 5
# Numero Numero swaps - permutacion 23 : 5
# Numero Numero swaps - permutacion 24 : 6
# Numero Numero swaps - permutacion 25 : 1
# Numero Numero swaps - permutacion 26 : 2
# Numero Numero swaps - permutacion 27 : 2
# Numero Numero swaps - permutacion 28 : 3
# Numero Numero swaps - permutacion 29 : 3
# Numero Numero swaps - permutacion 30 : 4
# Numero Numero swaps - permutacion 31 : 2
# Numero Numero swaps - permutacion 32 : 3
# Numero Numero swaps - permutacion 33 : 3
# Numero Numero swaps - permutacion 34 : 4
# Numero Numero swaps - permutacion 35 : 4
# Numero Numero swaps - permutacion 36 : 5
# Numero Numero swaps - permutacion 37 : 3
# Numero Numero swaps - permutacion 38 : 4
# Numero Numero swaps - permutacion 39 : 4
# Numero Numero swaps - permutacion 40 : 5
# Numero Numero swaps - permutacion 41 : 5
# Numero Numero swaps - permutacion 42 : 6
# Numero Numero swaps - permutacion 43 : 4
# Numero Numero swaps - permutacion 44 : 5
# Numero Numero swaps - permutacion 45 : 5
# Numero Numero swaps - permutacion 46 : 6
# Numero Numero swaps - permutacion 47 : 6
# Numero Numero swaps - permutacion 48 : 7
# Numero Numero swaps - permutacion 49 : 2
# Numero Numero swaps - permutacion 50 : 3
# Numero Numero swaps - permutacion 51 : 3
# Numero Numero swaps - permutacion 52 : 4
# Numero Numero swaps - permutacion 53 : 4
# Numero Numero swaps - permutacion 54 : 5
# Numero Numero swaps - permutacion 55 : 3
# Numero Numero swaps - permutacion 56 : 4
# Numero Numero swaps - permutacion 57 : 4
# Numero Numero swaps - permutacion 58 : 5
# Numero Numero swaps - permutacion 59 : 5
# Numero Numero swaps - permutacion 60 : 6
# Numero Numero swaps - permutacion 61 : 4
# Numero Numero swaps - permutacion 62 : 5
# Numero Numero swaps - permutacion 63 : 5
# Numero Numero swaps - permutacion 64 : 6
# Numero Numero swaps - permutacion 65 : 6
# Numero Numero swaps - permutacion 66 : 7
# Numero Numero swaps - permutacion 67 : 5
# Numero Numero swaps - permutacion 68 : 6
# Numero Numero swaps - permutacion 69 : 6
# Numero Numero swaps - permutacion 70 : 7
# Numero Numero swaps - permutacion 71 : 7
# Numero Numero swaps - permutacion 72 : 8
# Numero Numero swaps - permutacion 73 : 3
# Numero Numero swaps - permutacion 74 : 4
# Numero Numero swaps - permutacion 75 : 4
# Numero Numero swaps - permutacion 76 : 5
# Numero Numero swaps - permutacion 77 : 5
# Numero Numero swaps - permutacion 78 : 6
# Numero Numero swaps - permutacion 79 : 4
# Numero Numero swaps - permutacion 80 : 5
# Numero Numero swaps - permutacion 81 : 5
# Numero Numero swaps - permutacion 82 : 6
# Numero Numero swaps - permutacion 83 : 6
# Numero Numero swaps - permutacion 84 : 7
# Numero Numero swaps - permutacion 85 : 5
# Numero Numero swaps - permutacion 86 : 6
# Numero Numero swaps - permutacion 87 : 6
# Numero Numero swaps - permutacion 88 : 7
# Numero Numero swaps - permutacion 89 : 7
# Numero Numero swaps - permutacion 90 : 8
# Numero Numero swaps - permutacion 91 : 6
# Numero Numero swaps - permutacion 92 : 7
# Numero Numero swaps - permutacion 93 : 7
# Numero Numero swaps - permutacion 94 : 8
# Numero Numero swaps - permutacion 95 : 8
# Numero Numero swaps - permutacion 96 : 9
# Numero Numero swaps - permutacion 97 : 4
# Numero Numero swaps - permutacion 98 : 5
# Numero Numero swaps - permutacion 99 : 5
# Numero Numero swaps - permutacion 100 : 6
# Numero Numero swaps - permutacion 101 : 6
# Numero Numero swaps - permutacion 102 : 7
# Numero Numero swaps - permutacion 103 : 5
# Numero Numero swaps - permutacion 104 : 6
# Numero Numero swaps - permutacion 105 : 6
# Numero Numero swaps - permutacion 106 : 7
# Numero Numero swaps - permutacion 107 : 7
# Numero Numero swaps - permutacion 108 : 8
# Numero Numero swaps - permutacion 109 : 6
# Numero Numero swaps - permutacion 110 : 7
# Numero Numero swaps - permutacion 111 : 7
# Numero Numero swaps - permutacion 112 : 8
# Numero Numero swaps - permutacion 113 : 8
# Numero Numero swaps - permutacion 114 : 9
# Numero Numero swaps - permutacion 115 : 7
# Numero Numero swaps - permutacion 116 : 8
# Numero Numero swaps - permutacion 117 : 8
# Numero Numero swaps - permutacion 118 : 9
# Numero Numero swaps - permutacion 119 : 9
# Numero Numero swaps - permutacion 120 : 10
